# %% [markdown]
# <a href="https://colab.research.google.com/github/VinothRavi11/NLP/blob/main/NLP_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
input = "Hi I am Vinoth. How are you"
output1 = word_tokenize(input)
print(output1)
# Out:
# ['Hi', 'I', 'am', 'Vinoth', '.', 'How', 'are', 'you']

# %%
output2 = sent_tokenize(input)
print(output2)
# Out:
# ['Hi I am Vinoth.', 'How are you']

# %%
# !pip install -U spacy

# %%
# !python -m download en_core_web_sm
# Out:
# /usr/bin/python3: No module named download

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
input = "This is the second session"
doc = nlp(input)

# %%
for token in doc:
  print(token)
# Out:
# This
# is
# the
# second
# session

# %%
for sent in doc.sents:
  print(sent)
# Out:
# This is the second session
