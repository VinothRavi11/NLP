# %% [markdown]
# <a href="https://colab.research.google.com/github/VinothRavi11/NLP/blob/main/2nd%20exp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import csv

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-d457ae9b-684e-454d-9264-0cd0cfac0058" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d457ae9b-684e-454d-9264-0cd0cfac0058">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
output = pd.read_csv('/content/NLP notepad.txt',sep='\t')
print(output)
# Out:
# Empty DataFrame
# Columns: [Natural Processing Language]
# Index: []

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-3c34468c-d482-44ca-b2f4-e06556fe2211" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3c34468c-d482-44ca-b2f4-e06556fe2211">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
output = pd.read_csv('/content/Sheet_1.csv',sep='\t')
print(output)
# Out:
#                  response_id,class,response_text,,,,,
# 0   response_1,not_flagged,I try and avoid this so...
# 1   response_2,flagged,Had a friend open up to me ...
# 2   response_3,flagged,"I saved a girl from suicid...
# 3   response_4,not_flagged,i cant think of one rea...
# 4   response_5,not_flagged,"Only really one friend...
# ..                                                ...
# 75  response_76,not_flagged,"Now that I've been th...
# 76  response_77,flagged,when my best friends mom p...
# 77  response_78,not_flagged,As a camp counselor I ...
# 78  response_79,flagged,My now girlfriend used to ...
# 79  response_80,not_flagged,"The one person I ever...
#
# [80 rows x 1 columns]

# %%
import PyPDF2
pdf_file = open('/content/Concurrency and Computation - 2025 - Karapinar Senturk - Automated Classification of Skin Diseases Usi.pdf','rb')
reader = PyPDF2.PdfReader(pdf_file)
text = ""
for page in reader.pages:
  text += page.extract_text()
print(text)
pdf_file.close()
# Out:
# Concurrency and Computation: Practice and Experience
# RESEARCH ARTICLE OPEN ACCESS
# Automated Classification of Skin Diseases Using
# Microscopic Images: A Machine Learning Approach
# ZehraKarapinarSenturk1| RecepGuler2| YunusOzcan3| MehmetGamsizkan4
# 1ComputerEngineeringDepartment,FacultyofEngineering,DuzceUniversity,Düzce,Turkey |2Electrics-ElectronicsandComputerEngineering,Instituteof
# ScienceandTechnology,DuzceUniversity,Düzce,Turkey |3DepartmentofDermatology,FacultyofMedicine,DuzceUniversity,Düzce,Turkey |
# 4DepartmentofPathology,FacultyofMedicine,DuzceUniversity,Düzce,Turkey
# Correspondence: ZehraKarapinarSenturk( zehrakarapinar@duzce.edu.tr )
# Received: 6May2025 | Revised:20June2025 | Accepted: 5July2025
# Funding:Theauthorsreceivednospecificfundingforthiswork.
# Keywords: machinelearning | skindisease | wholeslideimage
# ABSTRACT
# This study presents a machine learning-based approach for the automated classification of skin diseases, specifically targeting
# ...

# %%
import requests
from bs4 import BeautifulSoup

# %%
input=requests.get('https://www.alliance.edu.in/')
input
# Out:
# <Response [200]>

# %%
input.content
# Out:
# b'<!DOCTYPE html>\r\n<html lang="en"> \r\n<head>\r\n<link rel="canonical" href="https://www.alliance.edu.in/" />\r\n\t\t<title>Alliance University | Bangalore Campus </title>\r\n    <meta charset="utf-8">\r\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n    <meta name="viewport" content="width=device-width, initial-scale=1">\r\n    <meta name="description" content="Alliance University Campus in Bangalore has state-of-the-art infrastructure with serene ambience. We offer graduate, post-graduate and certification courses.">\r\n    <meta name="keyword" content="alliance university campus, alliance university bangalore campus, alliance university city campus, alliance university campus area, alliance university central campus, alliance university btm layout campus, alliance btm campus">\r\n\t<meta name="google-site-verification" content="XI1MCM-3n3E5dvra-NV9ogVyfXCskOuBZv1WjIUeJik" />\r\n\t<meta name="facebook-domain-verification" content="dbcfzari3avtu79javik0x00ib8sgu" /
# ...

# %%
sb=BeautifulSoup(input.content,'html.parser')
sb.find_all('p')
# Out:
# [<p>Alliance University is a Private University established in Karnataka State by Act No.34 of year 2010 and is recognized by the University Grants Commission (UGC), New Delhi.</p>,
#  <p style="display:none;">The mission of the University is to create and sustain a community of lifelong learners in an environment that emphasizes literacy, critical thinking, and humanistic and scientific inquiry.</p>,
#  <p style="display:none;">CSR at the University encourages and propels students to imbibe the qualities of enlightened leadership and thereby instills in them a level of trust and confidence about themselves and the community.</p>,
# ...
